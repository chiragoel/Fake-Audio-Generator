# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/GANtastic3/MaskCycleGAN-VC.git
# Out:
# Cloning into 'MaskCycleGAN-VC'...
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 706 (delta 14), reused 7 (delta 2), pack-reused 676
# Receiving objects: 100% (706/706), 82.39 MiB | 37.68 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %%
# !pip install tensorboardX

# %%
# !pip install pyaudio

# %%
# %cd MaskCycleGAN-VC
# Out:
# /content/MaskCycleGAN-VC

# %%
# %cd ..
# Out:
# /content

# %%
# !python MaskCycleGAN-VC/data_preprocessing/preprocess_vcc2018.py \
  --data_directory /content/drive/My\ Drive/obama/dataset \
  --preprocessed_data_directory /content/drive/My\ Drive/obama/preprocessed_data \
  --speaker_ids ljspeech obamaspeech
# Out:
# Preprocessing data for speaker: ljspeech.
# Using cache found in /root/.cache/torch/hub/descriptinc_melgan-neurips_master
# Preprocess wav to mel:   0% 0/83 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# Preprocess wav to mel: 100% 83/83 [00:01<00:00, 51.88it/s]
# Preprocessed and saved data for speaker: ljspeech.
# Preprocessing data for speaker: obamaspeech.
# Using cache found in /root/.cache/torch/hub/descriptinc_melgan-neurips_master
# Preprocess wav to mel: 100% 94/94 [00:18<00:00,  4.99it/s]
# Preprocessed and saved data for speaker: obamaspeech.

# %%
# !python -W ignore::UserWarning -m mask_cyclegan_vc.train \
    --name mask_cyclegan_vc_ljspeech_obamaspeech \
    --seed 0 \
    --save_dir /content/drive/My\ Drive/obama/results/ \
    --preprocessed_data_dir /content/drive/My\ Drive/obama/preprocessed_data/ \
    --speaker_A_id ljspeech \
    --speaker_B_id obamaspeech \
    --epochs_per_save 10 \
    --epochs_per_plot 10 \
    --num_epochs 6172 \
    --batch_size 1 \
    --lr 5e-4 \
    --decay_after 1e4 \
    --sample_rate 22050 \
    --num_frames 64 \
    --max_mask_len 25 \
    --gpu_ids 0 \
    --continue_train
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                  ckpt_dir: /content/drive/My Drive/obama/results/mask_cyclegan_vc_ljspeech_obamaspeech/ckpts
#            continue_train: True
#         cycle_loss_lambda: 10
#               decay_after: 10000.0
#                    device: cuda
#          discriminator_lr: 0.0001
#           epochs_per_plot: 10
#           epochs_per_save: 10
#              generator_lr: 0.0002
#                   gpu_ids: ['cuda:0']
#      identity_loss_lambda: 5
#                   isTrain: True
#                load_epoch: 150
#                        lr: 0.0005
#                 max_ckpts: 3
#              max_mask_len: 25
#                      name: mask_cyclegan_vc_ljspeech_obamaspeech
#                num_epochs: 6172
#                num_frames: 64
#     num_frames_validation: 320
#     preprocessed_data_dir: /content/drive/My Drive/obama/preprocessed_data/
#               sample_rate: 22050
# ...
